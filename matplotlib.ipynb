# %% [markdown]
# <a href="https://colab.research.google.com/github/Praneeth1120/python_matplotlib/blob/module-5/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#plot graph
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,7,5,3])
y=np.array([5,10,8,1])
plt.plot(y,x,ls='-',color='g')
plt.show()

# %%
#plot graph 2
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,5,8,1])
y=np.array([7,10,3,10])
plt.plot(x,y,ls='-',color='r')
plt.show()

# %%
#plot graph 3
